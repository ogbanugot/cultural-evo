# %% [markdown]
# ### Model free learning

# %%
import numpy as np

# Define the agent class
class Agent:
    def __init__(self, num_actions, alpha=0.1, epsilon=0.1):
        self.num_actions = num_actions  # Number of possible actions
        self.alpha = alpha  # Learning rate
        self.epsilon = epsilon  # Exploration rate
        self.values = np.zeros(num_actions)  # Action values

    def choose_action(self):
        if np.random.rand() < self.epsilon:
            return np.random.choice(self.num_actions)  # Explore
        else:
            return np.argmax(self.values)  # Exploit

    def update_values(self, reward):
        self.values += self.alpha * (reward - np.mean(self.values))


# Cultural environment class
class CulturalEnvironment:
    def __init__(self, num_cultural_products):
        self.num_cultural_products = num_cultural_products  # Number of cultural products
        self.products = np.random.rand(num_cultural_products)  # Initialize cultural products
        self.products = np.array([10.9, 10.5, -90.5, 5.2, -50.4])
        self.experience = 0  # Initialize experience
        
    def interact_with_agent(self, agent):
        action = agent.choose_action()
        reward = self.products[action]  # Reward based on cultural product
        agent.update_values(reward)  # Update agent's values
        self.experience += reward  # Accumulate experience


# Define the main function for simulation
def main(num_episodes, num_actions, num_cultural_products):
    agent = Agent(num_actions)
    cultural_env = CulturalEnvironment(num_cultural_products)

    for episode in range(num_episodes):
        cultural_env.interact_with_agent(agent)

        print(f"Episode {episode + 1}: Experience = {cultural_env.experience}")

# %%
# Run the simulation
num_episodes = 50  # Number of episodes
num_actions = 5  # Number of possible actions
num_cultural_products = 5  # Number of cultural products

main(num_episodes, num_actions, num_cultural_products)
# Out:
# Episode 1: Experience = 10.9
# Episode 2: Experience = 21.8
# Episode 3: Experience = 32.7
# Episode 4: Experience = 43.6
# Episode 5: Experience = 54.5
# Episode 6: Experience = 65.4
# Episode 7: Experience = 76.30000000000001
# Episode 8: Experience = 87.20000000000002
# Episode 9: Experience = 98.10000000000002
# Episode 10: Experience = 109.00000000000003
# Episode 11: Experience = 18.50000000000003
# Episode 12: Experience = 29.400000000000027
# Episode 13: Experience = 40.300000000000026
# Episode 14: Experience = 51.200000000000024
# Episode 15: Experience = 62.10000000000002
# Episode 16: Experience = 73.00000000000003
# Episode 17: Experience = 83.90000000000003
# Episode 18: Experience = 94.80000000000004
# Episode 19: Experience = 105.70000000000005
# Episode 20: Experience = 116.60000000000005
# Episode 21: Experience = 127.50000000000006
# Episode 22: Experience = 138.40000000000006
# Episode 23: Experience = 148.90000000000006
# Episode 24: Experience = 159.80000000000007
# Episode 25: Experience = 170.70000000000007
# Episode 26: Experience = 181.60000000000008
# Episode 27: Experience = 192.50000000000009
# Episode 28: Experience = 203.4000000000001
# Episode 29: Experience = 214.3000000000001
# Episode 30: Experience = 225.2000000000001
# Episode 31: Experience = 236.1000000000001
# Episode 32: Experience = 247.0000000000001
# Episode 33: Experience = 257.9000000000001
# Episode 34: Experience = 268.80000000000007
# Episode 35: Experience = 279.70000000000005
# Episode 36: Experience = 290.6
# Episode 37: Experience = 301.5
# Episode 38: Experience = 312.4
# Episode 39: Experience = 323.29999999999995
# Episode 40: Experience = 334.19999999999993
# Episode 41: Experience = 345.0999999999999
# Episode 42: Experience = 355.9999999999999
# Episode 43: Experience = 366.89999999999986
# Episode 44: Experience = 377.79999999999984
# Episode 45: Experience = 388.6999999999998
# Episode 46: Experience = 399.5999999999998
# Episode 47: Experience = 410.4999999999998
# Episode 48: Experience = 421.39999999999975
# Episode 49: Experience = 432.2999999999997
# Episode 50: Experience = 443.1999999999997

# %% [markdown]
# ### Model-based learning with RNNs and VAEs
# - We use a VAE to learn a latent representation of the cultural environment or the agent's experiences.
# - An RNN is employed to model sequential dependencies in the agent's experiences over time.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
from torch.nn.utils.rnn import pack_sequence, pad_packed_sequence

# Agent class
class Agent(nn.Module):
    def __init__(self, num_actions, alpha=0.1, epsilon=0.1):
        super(Agent, self).__init__()
        self.num_actions = num_actions  # Number of possible actions
        self.alpha = alpha  # Learning rate
        self.epsilon = epsilon  # Exploration rate
        self.values = np.zeros(num_actions)  # Action values

    def choose_action(self):
        if np.random.rand() < self.epsilon:
            return np.random.choice(self.num_actions)  # Explore
        else:
            return np.argmax(self.values)  # Exploit

    def update_values(self, reward):
        self.values += self.alpha * (reward - np.mean(self.values))

# RNN-based agent class
class RNNAgent(Agent):
    def __init__(self, num_actions, input_size, hidden_size, alpha=0.1, epsilon=0.1):
        super().__init__(num_actions, alpha, epsilon)
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_actions)

    def forward(self, inputs):
        outputs, _ = self.rnn(inputs)
        outputs = self.fc(outputs[:, -1, :])  # Take the last output
        return outputs


# VAE model
class VAE(nn.Module):
    def __init__(self, input_size, latent_size):
        super(VAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Linear(64, latent_size * 2)  # 2 times latent_size for mean and variance
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_size, 64),
            nn.ReLU(),
            nn.Linear(64, input_size),
            nn.Sigmoid()  # Sigmoid for binary data, remove for continuous data
        )
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std
    
    def forward(self, x):
        x = x.view(-1, input_size)
        x = self.encoder(x)
        mu, logvar = x[:, :latent_size], x[:, latent_size:]
        z = self.reparameterize(mu, logvar)
        return self.decoder(z), mu, logvar

def normalize_tensor(tensor):
    # Find minimum and maximum values
    min_value = torch.min(tensor)
    max_value = torch.max(tensor)
    
    # Shift the range so that min_value becomes 0
    shifted_tensor = tensor - min_value
    
    # Scale the range to 0-1
    normalized_tensor = shifted_tensor / (max_value - min_value)
    
    return normalized_tensor


# Define the cultural environment class
class CulturalEnvironment:
    def __init__(self, num_cultural_products):
        self.num_cultural_products = num_cultural_products  # Number of cultural products
        self.products = torch.rand(num_cultural_products)  # Initialize cultural products
        print(self.products)
        self.experience = 0  # Initialize experience

    def interact_with_agent(self, agent, vae_model):
        # Convert cultural products to tensor
        cultural_tensor = torch.tensor(self.products).unsqueeze(0).unsqueeze(0)
        
        # Use RNN-based agent to predict action
        rnn_action_logits = agent(cultural_tensor)
        action = torch.argmax(rnn_action_logits).item()
        
        reward = self.products[action]  # Reward based on cultural product
#         agent.update_values(reward)  # Update agent's values
        
        # Use VAE model to reconstruct cultural products
        reconstructed_products, _, _ = vae_model(cultural_tensor.view(-1))
        target = cultural_tensor.view(-1).expand_as(reconstructed_products)
        
        # Accumulate experience based on both reconstruction error and reward
        reconstruction_loss = nn.functional.binary_cross_entropy(reconstructed_products, target)
        self.experience += reconstruction_loss.item() + reward

# Define the main function for simulation
def main(num_episodes, num_actions, num_cultural_products, input_size, hidden_size, latent_size):
    rnn_agent = RNNAgent(num_actions, input_size, hidden_size)
    vae_model = VAE(input_size, latent_size)
    
    # Define optimizer for RNN-based agent
    rnn_optimizer = optim.Adam(rnn_agent.parameters(), lr=0.1)
    
    # Define optimizer for VAE model
    vae_optimizer = optim.Adam(vae_model.parameters(), lr=0.1)
    cultural_env = CulturalEnvironment(num_cultural_products)

    for episode in range(num_episodes):        
        # Convert cultural products to tensor
        cultural_tensor = torch.tensor(cultural_env.products).unsqueeze(0).unsqueeze(0)
        
        # Train RNN-based agent
        rnn_optimizer.zero_grad()
        rnn_action_logits = rnn_agent(cultural_tensor)
        action = torch.argmax(rnn_action_logits).item()
        
        # Calculate reward based on the predicted action
        reward = cultural_env.products[action]
        
        # Calculate loss based on the negative reward
        rnn_loss = -torch.tensor(reward, dtype=torch.float, requires_grad=True)  # Convert reward to tensor
        
        # Backpropagate and update RNN-based agent's weights
        rnn_loss.backward()
        rnn_optimizer.step()
        
        # Train VAE model
        vae_optimizer.zero_grad()
        reconstructed_products, mu, logvar = vae_model(cultural_tensor.view(-1))
        target = cultural_tensor.view(-1).expand_as(reconstructed_products)
        vae_loss = nn.functional.binary_cross_entropy(reconstructed_products, target)
        vae_loss += -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
        vae_loss.backward()
        vae_optimizer.step()
        
        # Interact with the cultural environment
        cultural_env.interact_with_agent(rnn_agent, vae_model)

        print(f"Episode {episode + 1}: Experience = {cultural_env.experience}")

# %%
num_episodes = 1000  # Number of episodes
num_actions = 5  # Number of possible actions
num_cultural_products = 5  # Number of cultural products
input_size = num_cultural_products
hidden_size = 64
latent_size = 16

main(num_episodes, num_actions, num_cultural_products, input_size, hidden_size, latent_size)
# Out:
# tensor([0.2371, 0.8024, 0.2419, 0.5803, 0.4890])
# Episode 1: Experience = 1.2347447872161865
# Episode 2: Experience = 2.465806007385254
# Episode 3: Experience = 3.784947395324707
# Episode 4: Experience = 5.171415328979492
# Episode 5: Experience = 6.605747699737549
# Episode 6: Experience = 7.955357074737549
# Episode 7: Experience = 9.804990768432617
# Episode 8: Experience = 11.242969512939453
# Episode 9: Experience = 12.719045639038086
# Episode 10: Experience = 14.79166030883789
# Episode 11: Experience = 15.98777961730957
# Episode 12: Experience = 17.536455154418945
# Episode 13: Experience = 18.914997100830078
# Episode 14: Experience = 20.199386596679688
# Episode 15: Experience = 21.933517456054688
# Episode 16: Experience = 23.532747268676758
# Episode 17: Experience = 25.19172477722168
# Episode 18: Experience = 26.63846778869629
# Episode 19: Experience = 28.028663635253906
# Episode 20: Experience = 29.306621551513672
# Episode 21: Experience = 31.186582565307617
# Episode 22: Experience = 32.593360900878906
# Episode 23: Experience = 34.004878997802734
# Episode 24: Experience = 35.89533615112305
# Episode 25: Experience = 37.149253845214844
# Episode 26: Experience = 39.3322639465332
# Episode 27: Experience = 41.96025085449219
# Episode 28: Experience = 43.51722717285156
# Episode 29: Experience = 45.13249588012695
# Episode 30: Experience = 46.4471435546875
# Episode 31: Experience = 50.19304656982422
# Episode 32: Experience = 52.83367919921875
# Episode 33: Experience = 54.66383743286133
# Episode 34: Experience = 56.644187927246094
# Episode 35: Experience = 58.01188659667969
# Episode 36: Experience = 59.21699523925781
# Episode 37: Experience = 60.60606002807617
# Episode 38: Experience = 63.65468215942383
# Episode 39: Experience = 65.22101593017578
# Episode 40: Experience = 67.35277557373047
# Episode 41: Experience = 69.5212631225586
# Episode 42: Experience = 71.13418579101562
# Episode 43: Experience = 72.51322937011719
# Episode 44: Experience = 73.85369873046875
# Episode 45: Experience = 75.22806549072266
# Episode 46: Experience = 77.69329071044922
# Episode 47: Experience = 79.0821304321289
# Episode 48: Experience = 80.91232299804688
# Episode 49: Experience = 82.46904754638672
# Episode 50: Experience = 83.69060516357422
# Episode 51: Experience = 84.99308013916016
# Episode 52: Experience = 91.15615844726562
# Episode 53: Experience = 93.12559509277344
# Episode 54: Experience = 94.319091796875
# Episode 55: Experience = 95.65904998779297
# Episode 56: Experience = 97.63861083984375
# Episode 57: Experience = 99.18679809570312
# Episode 58: Experience = 100.94271850585938
# Episode 59: Experience = 102.8671875
# Episode 60: Experience = 104.296875
# Episode 61: Experience = 105.66519927978516
# Episode 62: Experience = 107.0687026977539
# Episode 63: Experience = 108.58038330078125
# Episode 64: Experience = 109.89665985107422
# Episode 65: Experience = 112.28763580322266
# Episode 66: Experience = 114.30974578857422
# Episode 67: Experience = 116.06132507324219
# Episode 68: Experience = 118.44564819335938
# Episode 69: Experience = 119.91850280761719
# Episode 70: Experience = 122.07594299316406
# Episode 71: Experience = 123.63365936279297
# Episode 72: Experience = 125.62994384765625
# Episode 73: Experience = 127.28760528564453
# Episode 74: Experience = 128.700439453125
# Episode 75: Experience = 129.90420532226562
# Episode 76: Experience = 131.23060607910156
# Episode 77: Experience = 132.6814422607422
# Episode 78: Experience = 134.5798797607422
# Episode 79: Experience = 136.80638122558594
# Episode 80: Experience = 138.05545043945312
# Episode 81: Experience = 139.32997131347656
# Episode 82: Experience = 140.9108428955078
# Episode 83: Experience = 142.1460418701172
# Episode 84: Experience = 143.45379638671875
# Episode 85: Experience = 145.15069580078125
# Episode 86: Experience = 147.30609130859375
# Episode 87: Experience = 149.17063903808594
# Episode 88: Experience = 150.4300537109375
# Episode 89: Experience = 151.63768005371094
# Episode 90: Experience = 153.39459228515625
# Episode 91: Experience = 154.57440185546875
# Episode 92: Experience = 155.75424194335938
# Episode 93: Experience = 157.83360290527344
# Episode 94: Experience = 159.22750854492188
# Episode 95: Experience = 160.45562744140625
# Episode 96: Experience = 161.646240234375
# Episode 97: Experience = 163.086181640625
# Episode 98: Experience = 164.43601989746094
# Episode 99: Experience = 166.135009765625
# Episode 100: Experience = 168.07650756835938
# Episode 101: Experience = 169.36048889160156
# Episode 102: Experience = 171.928955078125
# Episode 103: Experience = 173.7104949951172
# Episode 104: Experience = 174.9523162841797
# Episode 105: Experience = 176.19493103027344
# Episode 106: Experience = 177.3898162841797
# Episode 107: Experience = 178.56968688964844
# Episode 108: Experience = 179.81259155273438
# Episode 109: Experience = 181.0080108642578
# Episode 110: Experience = 182.21080017089844
# Episode 111: Experience = 183.71820068359375
# Episode 112: Experience = 184.9466094970703
# Episode 113: Experience = 187.32150268554688
# Episode 114: Experience = 188.54812622070312
# Episode 115: Experience = 189.73890686035156
# Episode 116: Experience = 191.6128387451172
# Episode 117: Experience = 193.0741729736328
# Episode 118: Experience = 194.64004516601562
# Episode 119: Experience = 195.9031524658203
# Episode 120: Experience = 197.50164794921875
# Episode 121: Experience = 198.87057495117188
# Episode 122: Experience = 200.4801788330078
# Episode 123: Experience = 201.73826599121094
# Episode 124: Experience = 203.75851440429688
# Episode 125: Experience = 205.9396209716797
# Episode 126: Experience = 207.1740264892578
# Episode 127: Experience = 208.8329620361328
# Episode 128: Experience = 210.104736328125
# Episode 129: Experience = 211.50784301757812
# Episode 130: Experience = 212.78952026367188
# Episode 131: Experience = 214.3723907470703
# Episode 132: Experience = 215.5604705810547
# Episode 133: Experience = 216.77352905273438
# Episode 134: Experience = 218.01158142089844
# Episode 135: Experience = 219.20706176757812
# Episode 136: Experience = 221.37046813964844
# Episode 137: Experience = 222.7627410888672
# Episode 138: Experience = 224.20204162597656
# Episode 139: Experience = 225.41949462890625
# Episode 140: Experience = 226.62274169921875
# Episode 141: Experience = 227.85714721679688
# Episode 142: Experience = 229.0386505126953
# Episode 143: Experience = 230.2664031982422
# Episode 144: Experience = 231.44876098632812
# Episode 145: Experience = 232.62986755371094
# Episode 146: Experience = 234.34963989257812
# Episode 147: Experience = 235.5667724609375
# Episode 148: Experience = 237.46304321289062
# Episode 149: Experience = 238.78561401367188
# Episode 150: Experience = 239.966064453125
# Episode 151: Experience = 241.17752075195312
# Episode 152: Experience = 242.50082397460938
# Episode 153: Experience = 243.77674865722656
# Episode 154: Experience = 244.98228454589844
# Episode 155: Experience = 246.16624450683594
# Episode 156: Experience = 247.34597778320312
# Episode 157: Experience = 248.54246520996094
# Episode 158: Experience = 249.7269287109375
# Episode 159: Experience = 250.90516662597656
# Episode 160: Experience = 252.08763122558594
# Episode 161: Experience = 253.2658233642578
# Episode 162: Experience = 254.58706665039062
# Episode 163: Experience = 255.79579162597656
# Episode 164: Experience = 256.9725646972656
# Episode 165: Experience = 258.43096923828125
# Episode 166: Experience = 259.9314880371094
# Episode 167: Experience = 261.1694641113281
# Episode 168: Experience = 262.34893798828125
# Episode 169: Experience = 263.524169921875
# Episode 170: Experience = 264.710693359375
# Episode 171: Experience = 265.924072265625
# Episode 172: Experience = 267.123291015625
# Episode 173: Experience = 268.44427490234375
# Episode 174: Experience = 269.7187194824219
# Episode 175: Experience = 270.8956298828125
# Episode 176: Experience = 272.07305908203125
# Episode 177: Experience = 273.32830810546875
# Episode 178: Experience = 274.5148010253906
# Episode 179: Experience = 275.7096252441406
# Episode 180: Experience = 276.99090576171875
# Episode 181: Experience = 278.2376403808594
# Episode 182: Experience = 279.4519958496094
# Episode 183: Experience = 280.6392517089844
# Episode 184: Experience = 281.8273620605469
# Episode 185: Experience = 283.0326232910156
# Episode 186: Experience = 284.2491455078125
# Episode 187: Experience = 286.802001953125
# Episode 188: Experience = 287.98455810546875
# Episode 189: Experience = 289.2795715332031
# Episode 190: Experience = 290.56512451171875
# Episode 191: Experience = 291.7663879394531
# Episode 192: Experience = 292.9700622558594
# Episode 193: Experience = 294.16656494140625
# Episode 194: Experience = 295.3621520996094
# Episode 195: Experience = 296.575439453125
# Episode 196: Experience = 297.81597900390625
# Episode 197: Experience = 299.0340270996094
# Episode 198: Experience = 300.22882080078125
# Episode 199: Experience = 301.54620361328125
# Episode 200: Experience = 303.1521911621094
# Episode 201: Experience = 304.3436279296875
# Episode 202: Experience = 305.76190185546875
# Episode 203: Experience = 306.95086669921875
# Episode 204: Experience = 308.1458435058594
# Episode 205: Experience = 309.3677062988281
# Episode 206: Experience = 310.585205078125
# Episode 207: Experience = 311.7715148925781
# Episode 208: Experience = 312.959228515625
# Episode 209: Experience = 314.2130432128906
# Episode 210: Experience = 315.42926025390625
# Episode 211: Experience = 316.6153564453125
# Episode 212: Experience = 317.8103942871094
# Episode 213: Experience = 319.02935791015625
# Episode 214: Experience = 320.3020935058594
# Episode 215: Experience = 321.48095703125
# Episode 216: Experience = 322.66455078125
# Episode 217: Experience = 323.86761474609375
# Episode 218: Experience = 325.0458984375
# Episode 219: Experience = 326.2454528808594
# Episode 220: Experience = 327.4710998535156
# Episode 221: Experience = 328.6959228515625
# Episode 222: Experience = 329.8862609863281
# Episode 223: Experience = 331.1784973144531
# Episode 224: Experience = 332.36279296875
# Episode 225: Experience = 333.56915283203125
# Episode 226: Experience = 334.7514953613281
# Episode 227: Experience = 336.077880859375
# Episode 228: Experience = 337.33612060546875
# Episode 229: Experience = 338.5148620605469
# Episode 230: Experience = 339.7409973144531
# Episode 231: Experience = 340.96514892578125
# Episode 232: Experience = 342.1468505859375
# Episode 233: Experience = 343.322998046875
# Episode 234: Experience = 344.50164794921875
# /var/folders/79/1ctp5wbn7xl2tv1s28h683kh0000gn/T/ipykernel_42999/2263971551.py:122: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cultural_tensor = torch.tensor(cultural_env.products).unsqueeze(0).unsqueeze(0)
# /var/folders/79/1ctp5wbn7xl2tv1s28h683kh0000gn/T/ipykernel_42999/2263971551.py:133: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rnn_loss = -torch.tensor(reward, dtype=torch.float, requires_grad=True)  # Convert reward to tensor
# /var/folders/79/1ctp5wbn7xl2tv1s28h683kh0000gn/T/ipykernel_42999/2263971551.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cultural_tensor = torch.tensor(self.products).unsqueeze(0).unsqueeze(0)
# Episode 235: Experience = 345.6907958984375
# Episode 236: Experience = 346.86572265625
# Episode 237: Experience = 348.0833740234375
# Episode 238: Experience = 349.2586975097656
# Episode 239: Experience = 350.5083312988281
# Episode 240: Experience = 352.4148864746094
# Episode 241: Experience = 353.59228515625
# Episode 242: Experience = 354.7670593261719
# Episode 243: Experience = 355.9439392089844
# Episode 244: Experience = 357.1185302734375
# Episode 245: Experience = 358.3800048828125
# Episode 246: Experience = 359.6277160644531
# Episode 247: Experience = 360.8028564453125
# Episode 248: Experience = 361.9930419921875
# Episode 249: Experience = 363.1926574707031
# Episode 250: Experience = 364.380859375
# Episode 251: Experience = 365.5575866699219
# Episode 252: Experience = 366.7651062011719
# Episode 253: Experience = 367.9941101074219
# Episode 254: Experience = 369.199951171875
# Episode 255: Experience = 370.3858642578125
# Episode 256: Experience = 371.5624084472656
# Episode 257: Experience = 372.7966003417969
# Episode 258: Experience = 374.0350341796875
# Episode 259: Experience = 375.2116394042969
# Episode 260: Experience = 376.66546630859375
# Episode 261: Experience = 377.84161376953125
# Episode 262: Experience = 379.01898193359375
# Episode 263: Experience = 380.19525146484375
# Episode 264: Experience = 381.37255859375
# Episode 265: Experience = 382.5487976074219
# Episode 266: Experience = 383.7789001464844
# Episode 267: Experience = 384.9544677734375
# Episode 268: Experience = 386.1658630371094
# Episode 269: Experience = 387.811279296875
# Episode 270: Experience = 388.9877014160156
# Episode 271: Experience = 390.16656494140625
# Episode 272: Experience = 391.34332275390625
# Episode 273: Experience = 392.5768127441406
# Episode 274: Experience = 393.7523193359375
# Episode 275: Experience = 394.94073486328125
# Episode 276: Experience = 396.2962341308594
# Episode 277: Experience = 397.49017333984375
# Episode 278: Experience = 398.66888427734375
# Episode 279: Experience = 399.8463439941406
# Episode 280: Experience = 401.0274963378906
# Episode 281: Experience = 402.2038879394531
# Episode 282: Experience = 403.4815979003906
# Episode 283: Experience = 404.6583251953125
# Episode 284: Experience = 405.835205078125
# Episode 285: Experience = 407.01153564453125
# Episode 286: Experience = 408.1875305175781
# Episode 287: Experience = 409.3672790527344
# Episode 288: Experience = 410.5484924316406
# Episode 289: Experience = 411.7614440917969
# Episode 290: Experience = 412.9607849121094
# Episode 291: Experience = 414.17913818359375
# Episode 292: Experience = 415.3555908203125
# Episode 293: Experience = 416.80987548828125
# Episode 294: Experience = 418.7706604003906
# Episode 295: Experience = 419.97357177734375
# Episode 296: Experience = 421.1882629394531
# Episode 297: Experience = 422.36383056640625
# Episode 298: Experience = 423.5397644042969
# Episode 299: Experience = 424.715087890625
# Episode 300: Experience = 425.89105224609375
# Episode 301: Experience = 427.06817626953125
# Episode 302: Experience = 428.2800598144531
# Episode 303: Experience = 429.4682922363281
# Episode 304: Experience = 430.77203369140625
# Episode 305: Experience = 431.9481201171875
# Episode 306: Experience = 433.1568603515625
# Episode 307: Experience = 434.33282470703125
# Episode 308: Experience = 435.520751953125
# Episode 309: Experience = 436.6962890625
# Episode 310: Experience = 437.87213134765625
# Episode 311: Experience = 439.0513916015625
# Episode 312: Experience = 440.22772216796875
# Episode 313: Experience = 441.4039306640625
# Episode 314: Experience = 442.5794677734375
# Episode 315: Experience = 443.75506591796875
# Episode 316: Experience = 444.9606628417969
# Episode 317: Experience = 446.1812744140625
# Episode 318: Experience = 447.3582763671875
# Episode 319: Experience = 448.5406799316406
# Episode 320: Experience = 449.7257080078125
# Episode 321: Experience = 450.91455078125
# Episode 322: Experience = 452.0892028808594
# Episode 323: Experience = 453.2658386230469
# Episode 324: Experience = 454.4451904296875
# Episode 325: Experience = 455.6199951171875
# Episode 326: Experience = 456.7966003417969
# Episode 327: Experience = 457.9739685058594
# Episode 328: Experience = 459.1499328613281
# Episode 329: Experience = 460.3244934082031
# Episode 330: Experience = 461.4992980957031
# Episode 331: Experience = 462.67529296875
# Episode 332: Experience = 463.85223388671875
# Episode 333: Experience = 465.0273132324219
# Episode 334: Experience = 466.20343017578125
# Episode 335: Experience = 467.37872314453125
# Episode 336: Experience = 468.5545349121094
# Episode 337: Experience = 469.7296447753906
# Episode 338: Experience = 470.9049987792969
# Episode 339: Experience = 472.15728759765625
# Episode 340: Experience = 473.332763671875
# Episode 341: Experience = 474.5079345703125
# Episode 342: Experience = 475.6873474121094
# Episode 343: Experience = 476.8664245605469
# Episode 344: Experience = 478.0652770996094
# Episode 345: Experience = 479.2425537109375
# Episode 346: Experience = 480.4172668457031
# Episode 347: Experience = 481.6755065917969
# Episode 348: Experience = 482.85040283203125
# Episode 349: Experience = 484.02520751953125
# Episode 350: Experience = 485.2002868652344
# Episode 351: Experience = 486.3755798339844
# Episode 352: Experience = 487.55181884765625
# Episode 353: Experience = 488.7289123535156
# Episode 354: Experience = 489.9124450683594
# Episode 355: Experience = 491.0965881347656
# Episode 356: Experience = 492.27667236328125
# Episode 357: Experience = 493.4664306640625
# Episode 358: Experience = 494.6477966308594
# Episode 359: Experience = 495.838134765625
# Episode 360: Experience = 497.0164489746094
# Episode 361: Experience = 498.1943664550781
# Episode 362: Experience = 499.3759765625
# Episode 363: Experience = 500.5831298828125
# Episode 364: Experience = 501.8067321777344
# Episode 365: Experience = 502.9918518066406
# Episode 366: Experience = 504.1800231933594
# Episode 367: Experience = 505.3817443847656
# Episode 368: Experience = 506.5605163574219
# Episode 369: Experience = 507.89892578125
# Episode 370: Experience = 509.0884094238281
# Episode 371: Experience = 510.2666320800781
# Episode 372: Experience = 511.5324401855469
# Episode 373: Experience = 512.72119140625
# Episode 374: Experience = 513.8973388671875
# Episode 375: Experience = 515.0734252929688
# Episode 376: Experience = 516.249267578125
# Episode 377: Experience = 517.4249267578125
# Episode 378: Experience = 518.6007080078125
# Episode 379: Experience = 519.77734375
# Episode 380: Experience = 520.9630737304688
# Episode 381: Experience = 522.1381225585938
# Episode 382: Experience = 523.3165283203125
# Episode 383: Experience = 524.5206909179688
# Episode 384: Experience = 525.695556640625
# Episode 385: Experience = 526.870361328125
# Episode 386: Experience = 528.0451049804688
# Episode 387: Experience = 529.2199096679688
# Episode 388: Experience = 530.4171752929688
# Episode 389: Experience = 531.59326171875
# Episode 390: Experience = 532.8056030273438
# Episode 391: Experience = 533.9806518554688
# Episode 392: Experience = 535.1568603515625
# Episode 393: Experience = 536.33154296875
# Episode 394: Experience = 537.51318359375
# Episode 395: Experience = 538.76513671875
# Episode 396: Experience = 539.93994140625
# Episode 397: Experience = 541.1171264648438
# Episode 398: Experience = 542.2949829101562
# Episode 399: Experience = 543.5460205078125
# Episode 400: Experience = 544.7219848632812
# Episode 401: Experience = 545.8972778320312
# Episode 402: Experience = 547.0730590820312
# Episode 403: Experience = 548.2484130859375
# Episode 404: Experience = 549.423828125
# Episode 405: Experience = 550.612548828125
# Episode 406: Experience = 551.7900390625
# Episode 407: Experience = 552.9652709960938
# Episode 408: Experience = 554.142333984375
# Episode 409: Experience = 555.3314819335938
# Episode 410: Experience = 556.5067138671875
# Episode 411: Experience = 557.6915893554688
# Episode 412: Experience = 558.8699340820312
# Episode 413: Experience = 560.0453491210938
# Episode 414: Experience = 561.2210693359375
# Episode 415: Experience = 562.3960571289062
# Episode 416: Experience = 563.588134765625
# Episode 417: Experience = 564.8137817382812
# Episode 418: Experience = 565.9886474609375
# Episode 419: Experience = 567.1635131835938
# Episode 420: Experience = 568.3688354492188
# Episode 421: Experience = 569.543701171875
# Episode 422: Experience = 570.7186279296875
# Episode 423: Experience = 571.8936157226562
# Episode 424: Experience = 573.0686645507812
# Episode 425: Experience = 574.2437133789062
# Episode 426: Experience = 575.4189453125
# Episode 427: Experience = 576.5977783203125
# Episode 428: Experience = 577.7989501953125
# Episode 429: Experience = 578.9740600585938
# Episode 430: Experience = 580.1492309570312
# Episode 431: Experience = 581.3244018554688
# Episode 432: Experience = 582.4995727539062
# Episode 433: Experience = 583.683837890625
# Episode 434: Experience = 584.8904418945312
# Episode 435: Experience = 586.0684204101562
# Episode 436: Experience = 587.2479248046875
# Episode 437: Experience = 588.4228515625
# Episode 438: Experience = 589.5978393554688
# Episode 439: Experience = 590.772705078125
# Episode 440: Experience = 591.947509765625
# Episode 441: Experience = 593.122314453125
# Episode 442: Experience = 594.3006591796875
# Episode 443: Experience = 595.4754028320312
# Episode 444: Experience = 596.71435546875
# Episode 445: Experience = 597.9464111328125
# Episode 446: Experience = 599.1210327148438
# Episode 447: Experience = 600.295654296875
# Episode 448: Experience = 601.4702758789062
# Episode 449: Experience = 602.6448364257812
# Episode 450: Experience = 603.8193969726562
# Episode 451: Experience = 604.9939575195312
# Episode 452: Experience = 606.1687622070312
# Episode 453: Experience = 607.3641357421875
# Episode 454: Experience = 608.5481567382812
# Episode 455: Experience = 609.7227172851562
# Episode 456: Experience = 610.9220581054688
# Episode 457: Experience = 612.0966796875
# Episode 458: Experience = 613.2845458984375
# Episode 459: Experience = 614.4674682617188
# Episode 460: Experience = 615.6422119140625
# Episode 461: Experience = 616.8175659179688
# Episode 462: Experience = 617.9928588867188
# Episode 463: Experience = 619.2074584960938
# Episode 464: Experience = 620.3829956054688
# Episode 465: Experience = 621.5619506835938
# Episode 466: Experience = 622.7374877929688
# Episode 467: Experience = 623.9129638671875
# Episode 468: Experience = 625.1005859375
# Episode 469: Experience = 626.2761840820312
# Episode 470: Experience = 627.451904296875
# Episode 471: Experience = 628.6275634765625
# Episode 472: Experience = 629.8031616210938
# Episode 473: Experience = 630.9822387695312
# Episode 474: Experience = 632.1575927734375
# Episode 475: Experience = 633.3328857421875
# Episode 476: Experience = 634.5081176757812
# Episode 477: Experience = 635.6832275390625
# Episode 478: Experience = 636.8582763671875
# Episode 479: Experience = 638.0790405273438
# Episode 480: Experience = 639.2539672851562
# Episode 481: Experience = 640.4293823242188
# Episode 482: Experience = 641.604248046875
# Episode 483: Experience = 642.7791137695312
# Episode 484: Experience = 643.9539794921875
# Episode 485: Experience = 645.1295166015625
# Episode 486: Experience = 646.3043823242188
# Episode 487: Experience = 647.4818725585938
# Episode 488: Experience = 648.65673828125
# Episode 489: Experience = 649.83154296875
# Episode 490: Experience = 651.0123291015625
# Episode 491: Experience = 652.1870727539062
# Episode 492: Experience = 653.3624877929688
# Episode 493: Experience = 654.537353515625
# Episode 494: Experience = 655.7124633789062
# Episode 495: Experience = 656.8872680664062
# Episode 496: Experience = 658.0620727539062
# Episode 497: Experience = 659.238037109375
# Episode 498: Experience = 660.4129028320312
# Episode 499: Experience = 661.5877685546875
# Episode 500: Experience = 662.7642211914062
# Episode 501: Experience = 663.9390869140625
# Episode 502: Experience = 665.1139526367188
# Episode 503: Experience = 666.288818359375
# Episode 504: Experience = 667.4639282226562
# Episode 505: Experience = 668.638671875
# Episode 506: Experience = 669.8134155273438
# Episode 507: Experience = 670.9880981445312
# Episode 508: Experience = 672.1627807617188
# Episode 509: Experience = 673.3572998046875
# Episode 510: Experience = 674.5322265625
# Episode 511: Experience = 675.7068481445312
# Episode 512: Experience = 676.8814086914062
# Episode 513: Experience = 678.0559692382812
# Episode 514: Experience = 679.2305297851562
# Episode 515: Experience = 680.4050903320312
# Episode 516: Experience = 681.5803833007812
# Episode 517: Experience = 682.75732421875
# Episode 518: Experience = 683.9318237304688
# Episode 519: Experience = 685.1063232421875
# Episode 520: Experience = 686.2808227539062
# Episode 521: Experience = 687.4622802734375
# Episode 522: Experience = 688.6367797851562
# Episode 523: Experience = 689.8116455078125
# Episode 524: Experience = 690.9861450195312
# Episode 525: Experience = 692.16064453125
# Episode 526: Experience = 693.3351440429688
# Episode 527: Experience = 694.5143432617188
# Episode 528: Experience = 695.6915283203125
# Episode 529: Experience = 696.8666381835938
# Episode 530: Experience = 698.0827026367188
# Episode 531: Experience = 699.2572631835938
# Episode 532: Experience = 700.4412841796875
# Episode 533: Experience = 701.6174926757812
# Episode 534: Experience = 702.7920532226562
# Episode 535: Experience = 703.9666137695312
# Episode 536: Experience = 705.1411743164062
# Episode 537: Experience = 706.3157348632812
# Episode 538: Experience = 707.4902954101562
# Episode 539: Experience = 708.6764526367188
# Episode 540: Experience = 709.8576049804688
# Episode 541: Experience = 711.0326538085938
# Episode 542: Experience = 712.2349243164062
# Episode 543: Experience = 713.4141845703125
# Episode 544: Experience = 714.5888671875
# Episode 545: Experience = 715.763427734375
# Episode 546: Experience = 716.9389038085938
# Episode 547: Experience = 718.1134643554688
# Episode 548: Experience = 719.2880249023438
# Episode 549: Experience = 720.4630126953125
# Episode 550: Experience = 721.6375732421875
# Episode 551: Experience = 722.8121337890625
# Episode 552: Experience = 723.989990234375
# Episode 553: Experience = 725.1646118164062
# Episode 554: Experience = 726.339111328125
# Episode 555: Experience = 727.5136108398438
# Episode 556: Experience = 728.6881103515625
# Episode 557: Experience = 729.8626098632812
# Episode 558: Experience = 731.037109375
# Episode 559: Experience = 732.2210083007812
# Episode 560: Experience = 733.395751953125
# Episode 561: Experience = 734.5702514648438
# Episode 562: Experience = 735.7457275390625
# Episode 563: Experience = 736.9203491210938
# Episode 564: Experience = 738.094970703125
# Episode 565: Experience = 739.2694702148438
# Episode 566: Experience = 740.4439697265625
# Episode 567: Experience = 741.6184692382812
# Episode 568: Experience = 742.79296875
# Episode 569: Experience = 743.9674682617188
# Episode 570: Experience = 745.1419677734375
# Episode 571: Experience = 746.3164672851562
# Episode 572: Experience = 747.490966796875
# Episode 573: Experience = 748.6654663085938
# Episode 574: Experience = 749.8399658203125
# Episode 575: Experience = 751.0144653320312
# Episode 576: Experience = 752.1928100585938
# Episode 577: Experience = 753.3673095703125
# Episode 578: Experience = 754.5418090820312
# Episode 579: Experience = 755.71630859375
# Episode 580: Experience = 756.8908081054688
# Episode 581: Experience = 758.066650390625
# Episode 582: Experience = 759.2413940429688
# Episode 583: Experience = 760.4160766601562
# Episode 584: Experience = 761.5908813476562
# Episode 585: Experience = 762.7670288085938
# Episode 586: Experience = 763.9425048828125
# Episode 587: Experience = 765.1177368164062
# Episode 588: Experience = 766.29296875
# Episode 589: Experience = 767.47265625
# Episode 590: Experience = 768.6480102539062
# Episode 591: Experience = 769.8234252929688
# Episode 592: Experience = 771.1233520507812
# Episode 593: Experience = 772.298828125
# Episode 594: Experience = 773.4783935546875
# Episode 595: Experience = 774.65380859375
# Episode 596: Experience = 775.8292236328125
# Episode 597: Experience = 777.0050048828125
# Episode 598: Experience = 778.1802978515625
# Episode 599: Experience = 779.35546875
# Episode 600: Experience = 780.5305786132812
# Episode 601: Experience = 781.70556640625
# Episode 602: Experience = 782.8804321289062
# Episode 603: Experience = 784.0552368164062
# Episode 604: Experience = 785.2302856445312
# Episode 605: Experience = 786.40673828125
# Episode 606: Experience = 787.5813598632812
# Episode 607: Experience = 788.7559204101562
# Episode 608: Experience = 789.9304809570312
# Episode 609: Experience = 791.1084594726562
# Episode 610: Experience = 792.2831420898438
# Episode 611: Experience = 793.4576416015625
# Episode 612: Experience = 794.6427001953125
# Episode 613: Experience = 795.8172607421875
# Episode 614: Experience = 796.992431640625
# Episode 615: Experience = 798.167236328125
# Episode 616: Experience = 799.341796875
# Episode 617: Experience = 800.5166625976562
# Episode 618: Experience = 801.6913452148438
# Episode 619: Experience = 802.8660278320312
# Episode 620: Experience = 804.0408325195312
# Episode 621: Experience = 805.2158203125
# Episode 622: Experience = 806.390625
# Episode 623: Experience = 807.5693359375
# Episode 624: Experience = 808.744140625
# Episode 625: Experience = 809.9189453125
# Episode 626: Experience = 811.0979614257812
# Episode 627: Experience = 812.272705078125
# Episode 628: Experience = 813.4474487304688
# Episode 629: Experience = 814.6221313476562
# Episode 630: Experience = 815.796875
# Episode 631: Experience = 816.9714965820312
# Episode 632: Experience = 818.1461181640625
# Episode 633: Experience = 819.3206787109375
# Episode 634: Experience = 820.4952392578125
# Episode 635: Experience = 821.6737060546875
# Episode 636: Experience = 822.8482055664062
# Episode 637: Experience = 824.022705078125
# Episode 638: Experience = 825.1972045898438
# Episode 639: Experience = 826.3717041015625
# Episode 640: Experience = 827.5462646484375
# Episode 641: Experience = 828.7207641601562
# Episode 642: Experience = 829.895263671875
# Episode 643: Experience = 831.0697631835938
# Episode 644: Experience = 832.2448120117188
# Episode 645: Experience = 833.4193725585938
# Episode 646: Experience = 834.5939331054688
# Episode 647: Experience = 835.7684936523438
# Episode 648: Experience = 836.9430541992188
# Episode 649: Experience = 838.11767578125
# Episode 650: Experience = 839.2931518554688
# Episode 651: Experience = 840.4677124023438
# Episode 652: Experience = 841.6422729492188
# Episode 653: Experience = 842.8168334960938
# Episode 654: Experience = 843.9913940429688
# Episode 655: Experience = 845.1659545898438
# Episode 656: Experience = 846.3405151367188
# Episode 657: Experience = 847.5150756835938
# Episode 658: Experience = 848.6896362304688
# Episode 659: Experience = 849.8641967773438
# Episode 660: Experience = 851.0387573242188
# Episode 661: Experience = 852.21337890625
# Episode 662: Experience = 853.387939453125
# Episode 663: Experience = 854.5625
# Episode 664: Experience = 855.7371215820312
# Episode 665: Experience = 856.9117431640625
# Episode 666: Experience = 858.0883178710938
# Episode 667: Experience = 859.262939453125
# Episode 668: Experience = 860.4379272460938
# Episode 669: Experience = 861.612548828125
# Episode 670: Experience = 862.7871704101562
# Episode 671: Experience = 863.9617309570312
# Episode 672: Experience = 865.1363525390625
# Episode 673: Experience = 866.3109130859375
# Episode 674: Experience = 867.4855346679688
# Episode 675: Experience = 868.66015625
# Episode 676: Experience = 869.8347778320312
# Episode 677: Experience = 871.0093383789062
# Episode 678: Experience = 872.1838989257812
# Episode 679: Experience = 873.3584594726562
# Episode 680: Experience = 874.5330200195312
# Episode 681: Experience = 875.7075805664062
# Episode 682: Experience = 876.8821411132812
# Episode 683: Experience = 878.056640625
# Episode 684: Experience = 879.2311401367188
# Episode 685: Experience = 880.4056396484375
# Episode 686: Experience = 881.5801391601562
# Episode 687: Experience = 882.754638671875
# Episode 688: Experience = 883.9291381835938
# Episode 689: Experience = 885.1036987304688
# Episode 690: Experience = 886.2872314453125
# Episode 691: Experience = 887.4617309570312
# Episode 692: Experience = 888.63623046875
# Episode 693: Experience = 889.8107299804688
# Episode 694: Experience = 890.9857177734375
# Episode 695: Experience = 892.1602172851562
# Episode 696: Experience = 893.3359375
# Episode 697: Experience = 894.5104370117188
# Episode 698: Experience = 895.6849365234375
# Episode 699: Experience = 896.8594970703125
# Episode 700: Experience = 898.0339965820312
# Episode 701: Experience = 899.20849609375
# Episode 702: Experience = 900.3829956054688
# Episode 703: Experience = 901.5575561523438
# Episode 704: Experience = 902.7320556640625
# Episode 705: Experience = 903.9066162109375
# Episode 706: Experience = 905.0811767578125
# Episode 707: Experience = 906.25830078125
# Episode 708: Experience = 907.4329223632812
# Episode 709: Experience = 908.6076049804688
# Episode 710: Experience = 909.7824096679688
# Episode 711: Experience = 910.9585571289062
# Episode 712: Experience = 912.1334838867188
# Episode 713: Experience = 913.3084716796875
# Episode 714: Experience = 914.4834594726562
# Episode 715: Experience = 915.6585083007812
# Episode 716: Experience = 916.83349609375
# Episode 717: Experience = 918.0084838867188
# Episode 718: Experience = 919.1834716796875
# Episode 719: Experience = 920.3583984375
# Episode 720: Experience = 921.5332641601562
# Episode 721: Experience = 922.7081298828125
# Episode 722: Experience = 924.5557861328125
# Episode 723: Experience = 925.7305297851562
# Episode 724: Experience = 926.9052734375
# Episode 725: Experience = 928.0799560546875
# Episode 726: Experience = 929.254638671875
# Episode 727: Experience = 930.4292602539062
# Episode 728: Experience = 931.6038818359375
# Episode 729: Experience = 932.7784423828125
# Episode 730: Experience = 933.9530029296875
# Episode 731: Experience = 935.1278076171875
# Episode 732: Experience = 936.302490234375
# Episode 733: Experience = 937.4773559570312
# Episode 734: Experience = 938.6524047851562
# Episode 735: Experience = 939.8276977539062
# Episode 736: Experience = 941.0104370117188
# Episode 737: Experience = 942.1859741210938
# Episode 738: Experience = 943.3643798828125
# Episode 739: Experience = 944.5399780273438
# Episode 740: Experience = 945.715576171875
# Episode 741: Experience = 946.8911743164062
# Episode 742: Experience = 948.0673217773438
# Episode 743: Experience = 949.2427368164062
# Episode 744: Experience = 950.41796875
# Episode 745: Experience = 951.5932006835938
# Episode 746: Experience = 952.7683715820312
# Episode 747: Experience = 953.9434204101562
# Episode 748: Experience = 955.118408203125
# Episode 749: Experience = 956.29345703125
# Episode 750: Experience = 957.46826171875
# Episode 751: Experience = 958.6430053710938
# Episode 752: Experience = 959.8178100585938
# Episode 753: Experience = 960.992431640625
# Episode 754: Experience = 962.1670532226562
# Episode 755: Experience = 963.3416137695312
# Episode 756: Experience = 964.5161743164062
# Episode 757: Experience = 965.6907348632812
# Episode 758: Experience = 966.8652954101562
# Episode 759: Experience = 968.0398559570312
# Episode 760: Experience = 969.2144165039062
# Episode 761: Experience = 970.3902587890625
# Episode 762: Experience = 971.5648193359375
# Episode 763: Experience = 972.7393798828125
# Episode 764: Experience = 973.9139404296875
# Episode 765: Experience = 975.533447265625
# Episode 766: Experience = 976.7080078125
# Episode 767: Experience = 977.882568359375
# Episode 768: Experience = 979.05712890625
# Episode 769: Experience = 980.231689453125
# Episode 770: Experience = 981.40625
# Episode 771: Experience = 982.580810546875
# Episode 772: Experience = 983.75537109375
# Episode 773: Experience = 984.9309692382812
# Episode 774: Experience = 986.1055297851562
# Episode 775: Experience = 987.2800903320312
# Episode 776: Experience = 988.4546508789062
# Episode 777: Experience = 989.6292114257812
# Episode 778: Experience = 990.8038330078125
# Episode 779: Experience = 991.978515625
# Episode 780: Experience = 993.1534423828125
# Episode 781: Experience = 994.328857421875
# Episode 782: Experience = 995.5147094726562
# Episode 783: Experience = 996.6907958984375
# Episode 784: Experience = 997.8673706054688
# Episode 785: Experience = 999.0430908203125
# Episode 786: Experience = 1000.2202758789062
# Episode 787: Experience = 1001.3972778320312
# Episode 788: Experience = 1002.5740966796875
# Episode 789: Experience = 1003.7510986328125
# Episode 790: Experience = 1004.927978515625
# Episode 791: Experience = 1006.104736328125
# Episode 792: Experience = 1007.28125
# Episode 793: Experience = 1008.45751953125
# Episode 794: Experience = 1009.633544921875
# Episode 795: Experience = 1010.808837890625
# Episode 796: Experience = 1011.984375
# Episode 797: Experience = 1013.1593627929688
# Episode 798: Experience = 1014.5068359375
# Episode 799: Experience = 1015.6818237304688
# Episode 800: Experience = 1016.856689453125
# Episode 801: Experience = 1018.0314331054688
# Episode 802: Experience = 1019.2061157226562
# Episode 803: Experience = 1020.3807373046875
# Episode 804: Experience = 1021.5553588867188
# Episode 805: Experience = 1022.7308959960938
# Episode 806: Experience = 1023.905517578125
# Episode 807: Experience = 1025.081298828125
# Episode 808: Experience = 1026.2559814453125
# Episode 809: Experience = 1027.4306640625
# Episode 810: Experience = 1028.6053466796875
# Episode 811: Experience = 1029.7845458984375
# Episode 812: Experience = 1030.95947265625
# Episode 813: Experience = 1032.13525390625
# Episode 814: Experience = 1033.31005859375
# Episode 815: Experience = 1034.4853515625
# Episode 816: Experience = 1035.705078125
# Episode 817: Experience = 1036.8807373046875
# Episode 818: Experience = 1038.0555419921875
# Episode 819: Experience = 1039.2303466796875
# Episode 820: Experience = 1040.406005859375
# Episode 821: Experience = 1041.580810546875
# Episode 822: Experience = 1042.755615234375
# Episode 823: Experience = 1043.930419921875
# Episode 824: Experience = 1045.105224609375
# Episode 825: Experience = 1046.2801513671875
# Episode 826: Experience = 1047.4552001953125
# Episode 827: Experience = 1048.6318359375
# Episode 828: Experience = 1049.807373046875
# Episode 829: Experience = 1051.0001220703125
# Episode 830: Experience = 1052.1759033203125
# Episode 831: Experience = 1053.3519287109375
# Episode 832: Experience = 1054.52783203125
# Episode 833: Experience = 1055.7037353515625
# Episode 834: Experience = 1056.8792724609375
# Episode 835: Experience = 1058.0548095703125
# Episode 836: Experience = 1059.23046875
# Episode 837: Experience = 1060.406005859375
# Episode 838: Experience = 1061.5814208984375
# Episode 839: Experience = 1062.756591796875
# Episode 840: Experience = 1063.9410400390625
# Episode 841: Experience = 1065.115966796875
# Episode 842: Experience = 1066.2908935546875
# Episode 843: Experience = 1067.4658203125
# Episode 844: Experience = 1068.6405029296875
# Episode 845: Experience = 1069.8154296875
# Episode 846: Experience = 1070.9903564453125
# Episode 847: Experience = 1072.1654052734375
# Episode 848: Experience = 1073.3404541015625
# Episode 849: Experience = 1074.5155029296875
# Episode 850: Experience = 1075.697509765625
# Episode 851: Experience = 1076.8724365234375
# Episode 852: Experience = 1078.04736328125
# Episode 853: Experience = 1079.2222900390625
# Episode 854: Experience = 1080.3970947265625
# Episode 855: Experience = 1081.5718994140625
# Episode 856: Experience = 1082.7467041015625
# Episode 857: Experience = 1083.92138671875
# Episode 858: Experience = 1085.0960693359375
# Episode 859: Experience = 1086.2716064453125
# Episode 860: Experience = 1087.4466552734375
# Episode 861: Experience = 1088.6212158203125
# Episode 862: Experience = 1089.7957763671875
# Episode 863: Experience = 1090.9703369140625
# Episode 864: Experience = 1092.1448974609375
# Episode 865: Experience = 1093.3194580078125
# Episode 866: Experience = 1094.4940185546875
# Episode 867: Experience = 1095.668701171875
# Episode 868: Experience = 1096.84326171875
# Episode 869: Experience = 1098.017822265625
# Episode 870: Experience = 1099.1923828125
# Episode 871: Experience = 1100.366943359375
# Episode 872: Experience = 1101.54150390625
# Episode 873: Experience = 1102.716064453125
# Episode 874: Experience = 1103.890625
# Episode 875: Experience = 1105.065185546875
# Episode 876: Experience = 1106.23974609375
# Episode 877: Experience = 1107.48974609375
# Episode 878: Experience = 1108.664306640625
# Episode 879: Experience = 1109.8388671875
# Episode 880: Experience = 1111.013427734375
# Episode 881: Experience = 1112.18798828125
# Episode 882: Experience = 1113.362548828125
# Episode 883: Experience = 1114.537109375
# Episode 884: Experience = 1115.711669921875
# Episode 885: Experience = 1116.88623046875
# Episode 886: Experience = 1118.062255859375
# Episode 887: Experience = 1119.23681640625
# Episode 888: Experience = 1121.537353515625
# Episode 889: Experience = 1122.7119140625
# Episode 890: Experience = 1123.886474609375
# Episode 891: Experience = 1125.06103515625
# Episode 892: Experience = 1126.2357177734375
# Episode 893: Experience = 1127.4102783203125
# Episode 894: Experience = 1128.5848388671875
# Episode 895: Experience = 1129.7652587890625
# Episode 896: Experience = 1130.9405517578125
# Episode 897: Experience = 1132.1165771484375
# Episode 898: Experience = 1133.29345703125
# Episode 899: Experience = 1134.47119140625
# Episode 900: Experience = 1135.6497802734375
# Episode 901: Experience = 1136.8289794921875
# Episode 902: Experience = 1138.01611328125
# Episode 903: Experience = 1139.196044921875
# Episode 904: Experience = 1140.375732421875
# Episode 905: Experience = 1141.5550537109375
# Episode 906: Experience = 1142.780029296875
# Episode 907: Experience = 1143.958251953125
# Episode 908: Experience = 1145.5263671875
# Episode 909: Experience = 1146.7030029296875
# Episode 910: Experience = 1147.8790283203125
# Episode 911: Experience = 1149.054443359375
# Episode 912: Experience = 1150.3050537109375
# Episode 913: Experience = 1151.4798583984375
# Episode 914: Experience = 1152.6544189453125
# Episode 915: Experience = 1153.82958984375
# Episode 916: Experience = 1155.004150390625
# Episode 917: Experience = 1156.1788330078125
# Episode 918: Experience = 1157.3536376953125
# Episode 919: Experience = 1158.5286865234375
# Episode 920: Experience = 1159.704833984375
# Episode 921: Experience = 1160.8804931640625
# Episode 922: Experience = 1162.056396484375
# Episode 923: Experience = 1163.2325439453125
# Episode 924: Experience = 1164.60107421875
# Episode 925: Experience = 1166.3504638671875
# Episode 926: Experience = 1167.525390625
# Episode 927: Experience = 1168.7012939453125
# Episode 928: Experience = 1169.8780517578125
# Episode 929: Experience = 1171.0535888671875
# Episode 930: Experience = 1172.2288818359375
# Episode 931: Experience = 1173.404541015625
# Episode 932: Experience = 1174.5806884765625
# Episode 933: Experience = 1175.7628173828125
# Episode 934: Experience = 1176.939697265625
# Episode 935: Experience = 1178.1168212890625
# Episode 936: Experience = 1179.2958984375
# Episode 937: Experience = 1180.4736328125
# Episode 938: Experience = 1181.6531982421875
# Episode 939: Experience = 1182.83154296875
# Episode 940: Experience = 1184.010009765625
# Episode 941: Experience = 1185.1884765625
# Episode 942: Experience = 1186.3668212890625
# Episode 943: Experience = 1187.5655517578125
# Episode 944: Experience = 1188.9263916015625
# Episode 945: Experience = 1190.4708251953125
# Episode 946: Experience = 1191.647705078125
# Episode 947: Experience = 1195.2501220703125
# Episode 948: Experience = 1196.426513671875
# Episode 949: Experience = 1201.0806884765625
# Episode 950: Experience = 1202.256103515625
# Episode 951: Experience = 1203.442626953125
# Episode 952: Experience = 1204.6175537109375
# Episode 953: Experience = 1205.792724609375
# Episode 954: Experience = 1206.96826171875
# Episode 955: Experience = 1208.144287109375
# Episode 956: Experience = 1209.320556640625
# Episode 957: Experience = 1210.4976806640625
# Episode 958: Experience = 1211.6751708984375
# Episode 959: Experience = 1212.85302734375
# Episode 960: Experience = 1214.03125
# Episode 961: Experience = 1215.2100830078125
# Episode 962: Experience = 1216.5416259765625
# Episode 963: Experience = 1217.7216796875
# Episode 964: Experience = 1218.9022216796875
# Episode 965: Experience = 1220.083740234375
# Episode 966: Experience = 1222.100830078125
# Episode 967: Experience = 1223.2830810546875
# Episode 968: Experience = 1224.46533203125
# Episode 969: Experience = 1225.6473388671875
# Episode 970: Experience = 1226.8218994140625
# Episode 971: Experience = 1228.0048828125
# Episode 972: Experience = 1229.1875
# Episode 973: Experience = 1230.36669921875
# Episode 974: Experience = 1231.5469970703125
# Episode 975: Experience = 1232.7703857421875
# Episode 976: Experience = 1233.951904296875
# Episode 977: Experience = 1235.1318359375
# Episode 978: Experience = 1236.3143310546875
# Episode 979: Experience = 1237.4931640625
# Episode 980: Experience = 1238.749755859375
# Episode 981: Experience = 1239.9273681640625
# Episode 982: Experience = 1241.1043701171875
# Episode 983: Experience = 1242.280517578125
# Episode 984: Experience = 1243.4566650390625
# Episode 985: Experience = 1244.6324462890625
# Episode 986: Experience = 1245.80859375
# Episode 987: Experience = 1246.98388671875
# Episode 988: Experience = 1248.1590576171875
# Episode 989: Experience = 1249.3399658203125
# Episode 990: Experience = 1250.514892578125
# Episode 991: Experience = 1251.6898193359375
# Episode 992: Experience = 1252.8729248046875
# Episode 993: Experience = 1254.066650390625
# Episode 994: Experience = 1255.241455078125
# Episode 995: Experience = 1256.506591796875
# Episode 996: Experience = 1257.6849365234375
# Episode 997: Experience = 1258.8597412109375
# Episode 998: Experience = 1260.0345458984375
# Episode 999: Experience = 1261.2093505859375
# Episode 1000: Experience = 1262.3841552734375
